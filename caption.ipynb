# %%
from dataset import create_dateloaders

# %%
train_loader, val_loader,vocab = create_dateloaders()
# Out:
# A man in street racer armor be examine the tire of another racer 's motorbike .
# ***** tokenizer ['A', 'man', 'in', 'street', 'racer', 'armor', 'be', 'examine', 'the', 'tire', 'of', 'another', 'racer', "'s", 'motorbike', '.']
# ***** loader ['A', 'man', 'in', 'street', 'racer', 'armor', 'be', 'examine', 'the', 'tire', 'of', 'another', 'racer', "'s", 'motorbike', '.']
# ***** tokenizer ['A', 'man', 'in', 'street', 'racer', 'armor', 'be', 'examine', 'the', 'tire', 'of', 'another', 'racer', "'s", 'motorbike', '.']
# Two racer drive a white bike down a road .
# ***** tokenizer ['Two', 'racer', 'drive', 'a', 'white', 'bike', 'down', 'a', 'road', '.']
# ***** loader ['Two', 'racer', 'drive', 'a', 'white', 'bike', 'down', 'a', 'road', '.']
# ***** tokenizer ['Two', 'racer', 'drive', 'a', 'white', 'bike', 'down', 'a', 'road', '.']
# Two motorist be ride along on their vehicle that be oddly design and color .
# ...

# %%
for idx, (x, y) in enumerate(train_loader):
    print("************* idx *************", idx)
    print(x.shape, y.shape)
    break
# Out:
# ***** tokenizer ['Firefighter', 'use', 'water', 'to', 'extinguish', 'a', 'car', 'that', 'be', 'on', 'fire', '.']
# ***** tokenizer ['A', 'boy', 'sand', 'surf', 'down', 'a', 'hill']
# ***** tokenizer ['A', 'bare', 'backed', 'climber', 'be', 'attach', 'to', 'the', 'rock', 'face', 'on', 'a', 'pink', 'safety', 'rope', '.']
# ***** tokenizer ['Three', 'child', 'squeeze', 'into', 'a', 'plastic', 'tub', 'fill', 'with', 'water', 'and', 'play', '.']
# ***** tokenizer ['a', 'lone', 'rock', 'climber', 'in', 'a', 'harness', 'climb', 'a', 'huge', 'rock', 'wall', '.']
# ***** tokenizer ['Two', 'motorist', 'be', 'ride', 'along', 'on', 'their', 'vehicle', 'that', 'be', 'oddly', 'design', 'and', 'color', '.']
# ***** tokenizer ['Two', 'person', 'be', 'in', 'a', 'small', 'race', 'car', 'drive', 'by', 'a', 'green', 'hill', '.']
# ***** tokenizer ['A', 'man', 'be', 'surf', 'down', 'a', 'hill', 'of', 'sand', '.']
# ...

# %%
##
